# %%
from bertviz.pytorch_transformers_attn import BertModel, BertTokenizer
# from pytorch_pretrained_bert.tokenization import BertTokenizer
from bertviz.model_view import show
from bertviz.run_classifier import BertForMultiLabelSequenceClassification
from pytorch_pretrained_bert.modeling import BertConfig
import os

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;
# require.config({
#   paths: {
#       d3: '//cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min',
#     jquery: '//ajax.googleapis.com/ajax/libs/jquery/2.0.0/jquery.min',
#   }
# });

# %%
model_type = 'bert'
model_version = 'bert-base-uncased'
do_lower_case = True

model = BertModel.from_pretrained(model_version)
tokenizer = BertTokenizer.from_pretrained(model_version, do_lower_case=do_lower_case)

# model = BertModel.from_pretrained(os.path.join('models', 'sb_all_0'))
# tokenizer = BertTokenizer.from_pretrained(model_version, do_lower_case=do_lower_case)


sentence_a = "Mild focal narrowing at right MCA distal M1 segment"
sentence_b = "Mild focal narrowing at right MCA distal M1 segment"
show(model, model_type, tokenizer, sentence_a, sentence_b)
# Out:
# 10/16/2019 15:52:18 - INFO - bertviz.pytorch_transformers_attn.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at C:\Users\linc9\.cache\torch\pytorch_transformers\4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.bf3b9ea126d8c0001ee8a1e8b92229871d06d36d8808208cc2449280da87785c
# 10/16/2019 15:52:18 - INFO - bertviz.pytorch_transformers_attn.modeling_utils -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# ...
